# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_pickle("Data/New/Main_Data/Dataset.pkl")

# %%
data.head()
# Out:
#        Country  Year      Status Life_Expectancy Adult_Mortality  \
# 0  Afghanistan  2014  Low income              63             234
# 1  Afghanistan  2013  Low income            62.7             235
# 2  Afghanistan  2012  Low income            62.2             242
# 3  Afghanistan  2011  Low income            61.7             248
# 4  Afghanistan  2010  Low income            61.2             255
#
#   Infant_Deaths Alcohol Percentage_Expenditure Measles BMI_5-19_years  \
# 0            64    0.03                    9.7     492           17.2
# 1            66    0.03                    8.8     430           17.1
# 2            69    0.04                    7.9    2787           17.0
# 3            71    0.04                    8.6    3013           16.9
# 4            74    0.03                    8.6    1989           16.8
#
#      ...    Under-Five_Deaths Polio Total_Expenditure Diphtheria      GDP  \
# 0    ...                   86    58                12         62   625.34
# ...
