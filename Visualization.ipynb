# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_pickle("Data/New/Main_Data/Dataset.pkl")

# %%
data.head()
# Out:
#        Country  Year      Status Life_Expectancy Adult_Mortality  \
# 0  Afghanistan  2014  Low income              63             234
# 1  Afghanistan  2013  Low income            62.7             235
# 2  Afghanistan  2012  Low income            62.2             242
# 3  Afghanistan  2011  Low income            61.7             248
# 4  Afghanistan  2010  Low income            61.2             255
#
#   Infant_Deaths Alcohol Percentage_Expenditure Measles BMI_5-19_years  \
# 0            64    0.03                    9.7     492           17.2
# 1            66    0.03                    8.8     430           17.1
# 2            69    0.04                    7.9    2787           17.0
# 3            71    0.04                    8.6    3013           16.9
# 4            74    0.03                    8.6    1989           16.8
#
#      ...    Under-Five_Deaths Polio Total_Expenditure Diphtheria      GDP  \
# 0    ...                   86    58                12         62   625.34
# ...

# %%
plt.hist(data['Percentage_Expenditure'], facecolor = 'peru', edgecolor= 'blue', bins=8)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6575: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6576: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-55fcc3a2ec32> in <module>
# ----> 1 plt.hist(data['Percentage_Expenditure'], facecolor = 'peru', edgecolor= 'blue', bins=8)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
# ...
