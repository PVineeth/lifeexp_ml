# %%
import pandas as pd

# %%
totalex = pd.read_csv("data.csv")

# %%
#totalex.info()
totalex.columns[1]
# Out:
# '2014'

# %%
totalex['Country']
count = 0
df = pd.DataFrame(columns=['Country', 'Year', 'Total_Expenditure'])
for i in range(0, len(totalex['Country'].unique())):
    for j in range(1, len(totalex.columns)):
        #print(totalex.loc[i,'Country'], end='')
        df.at[count, 'Country'] = totalex.loc[i,'Country']
        df.at[count, 'Year'] = totalex.columns[j]
       # print(totalex.columns[j])
        df.at[count, 'Total_Expenditure'] = totalex[totalex['Country'] == totalex['Country'][i]].T[1:].loc[totalex.columns[j]].values[0]
        count+=1

# %%
type(totalex[totalex['Country'] == totalex['Country'][0]].T[1:].loc[totalex.columns[1]].values)
# tmp.reset_index(level=0, inplace=True)
# tmp.columns = ['Year','Total_Expenditure']
# tmp
# Out:
# numpy.ndarray

# %%
df.head(100)
# Out:
#                 Country  Year Total_Expenditure
# 0           Afghanistan  2014                12
# 1           Afghanistan  2013             10.59
# 2           Afghanistan  2012             11.67
# 3           Afghanistan  2011             10.17
# 4           Afghanistan  2010              14.4
# 5           Afghanistan  2009             12.73
# 6           Afghanistan  2008              6.93
# 7           Afghanistan  2007              2.95
# 8           Afghanistan  2006               6.3
# 9           Afghanistan  2005              5.49
# 10          Afghanistan  2004              6.98
# 11          Afghanistan  2003              5.58
# 12          Afghanistan  2002              8.99
# 13          Afghanistan  2001               NaN
# 14          Afghanistan  2000               NaN
# 15              Albania  2014              9.37
# 16              Albania  2013              9.76
# 17              Albania  2012              9.71
# 18              Albania  2011              9.85
# ...

# %%
df.to_csv("file.csv")
