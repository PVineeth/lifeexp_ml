# %% [markdown]
# <h1 align="center"> Exploring & Predicting Life Expectancy to Improve Policy Decisions </h1>
# <h2 align="center">Descriptive & Predictive Analysis on factors influencing Life Expectancy</h2>
# <h3 align="center"> Group 8</h3>
# <h4 align="center">Samir Bhargava, Sandeep Bijinapalli, Swetha Papaiahgari, Vineeth Penugonda</h4>

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# The World Health Organization (WHO) is a specialized agency of the United Nations that is concerned with international public health. It was established on 7 April 1948, and is headquartered in Geneva, Switzerland.
# The Global Health Observatory (GHO) data repository under WHO keeps track of the health status as well as many other related factors for all countries. According to WHO, in the past 15 years, there has been a huge development in health sector resulting in improvement of human mortality rates especially in the developing nations in comparison to the past 30 years.
#
# **Life expectancy** refers to the number of years a person is expected to live based on the statistical average. Life expectancy is one of the key measures of a population’s health, and an indicator used widely by policymakers and researchers to complement economic measures of prosperity, such as GDP per capita. The life expectancy for a particular person or population group depends on several variables such as their lifestyle, access to healthcare, diet, economical status and the relevant mortality and morbidity data.
#
# Although there have been lot of studies undertaken in the past on factors affecting life expectancy considering demographic variables, income composition and mortality rates. It was found that affect of immunization and human development index was not taken into account in the past. Also, some of the past research was done based on data set of one year for all the countries.

# %% [markdown]
# So, this study will focus on immunization factors, mortality factors, economic factors, social factors and other health related factors as well. Important immunization like Hepatitis B, Polio and Diphtheria will also be considered. Since the observations in this dataset are based on different countries, it will be easier for a country to determine the predicting factor which is contributing to lower value of life expectancy. This will help in suggesting a country, which area should be given importance in order to efficiently improve the life expectancy of its population.

# %% [markdown]
# In this project, we want to conduct an exploratory study on the life expectancy and factors influencing it. Specifically, we want to answer the following research questions:
#
# 1. What are the predicting variables actually affecting the life expectancy?
# 2. Should a country having a lower life expectancy value increase its healthcare expenditure in order to improve its average lifespan?
# 3. How does Infant and Adult mortality rates affect life expectancy?
# 4. Does Life Expectancy has positive or negative correlation with eating habits, lifestyle, exercise, smoking, drinking alcohol etc.
# 5. Do densely populated countries tend to have lower life expectancy?
# 6. What is the impact of Immunization coverage on life expectancy?

# %% [markdown]
# # 2. Data

# %% [markdown]
# The dataset was downloaded from the following kaggle link:
#
# https://www.kaggle.com/kumarajarshi/life-expectancy-who/
#
# The data-set related to life expectancy, health factors for 138 countries has been collected from the same WHO data repository website and its corresponding economic data was collected from United Nation website. In this project we have considered data from year 2000-2015 for 138 countries for further analysis. Among all categories of health-related factors only those critical factors were chosen which are more representative. The individual data files have been merged together into a single data-set.
#
# The final merged file (final dataset) consists of 21 Columns and 2070 rows which meant 20 predicting variables. All predicting variables was then divided into several broad categories:​Immunization related factors, Mortality factors, Economical factors and Social factors.

# %% [markdown]
# ### Key Information In The Dataset

# %% [markdown]
# - **Country**: Country
# - **Year**: Year
# - **Status**: Developed or Developing status
# - **Life expectancy**: Life Expectancy in age
# - **Adult Mortality**: Adult Mortality Rates of both sexes (probability of dying between 15 and 60 years per 1000 population)
# - **infant deaths**: Number of Infant Deaths per 1000 population
# - **Alcohol**: Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)
# - **percentage expenditure**: Expenditure on health as a percentage of Gross Domestic Product per capita(%)
# - **Measles**: Measles - number of reported cases per 1000 population
# - **BMI_5-19_years**: Mean body mass index trends among children and adolescents, crude (kg/m²), Estimates by country, among children aged 5-19 years
# - **BMI_18+_years**: Mean body mass index trends among adults, crude (kg/m²), Estimates by country for people whose age is above 18
# - **under-five deaths**: Number of under-five deaths per 1000 population
# - **Polio**: Polio (Pol3) immunization coverage among 1-year-olds (%)
# - **Total expenditure**: General government expenditure on health as a percentage of total government expenditure (%)
# - **Diphtheria**: Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)
# - **GDP**: Gross Domestic Product per capita (in USD)
# - **Population**: Population of the country
# - **thinness 1-19 years**: Prevalence of thinness among children and adolescents for Age 10 to 19 (%)
# - **thinness 5-9 years**: Prevalence of thinness among children for Age 5 to 9(%)
# - **Income composition of resources**: Human Development Index in terms of income composition of resources (index ranging from 0 to 1)
# - **Schooling**: Number of years of Schooling (years)

# %% [markdown]
# # 3. Timeline

# %% [markdown]
# | Tasks | Activity   | Start/Complete Date   |
# |------|------|------|
# | Data Exploration  | Explore dataset | 2/22 - 3/1|
# | Data Analysis I  | Data Remodelling, Data Manipulation | 3/2 - 3/16|
# | Data Analysis II  | Create Visualizations, Gather Insights  | 3/17 - 3/31 (Project M2: 3/31)|
# | Predictive Analysis |   Work on the Machine Learning part of the project   | 4/1 - 4/14|
# | Presentation Preparation |   List the important topics that will need to be covered during the presentation, Assign slides to team members, Final check of the slides before the presentation   | 4/15 - 4/21|
# | Write Report |   Gather requirements for the report, Assign sections within the report to team members, Finalize the report   | 4/22 - 5/5|
# | Presentation  | Project Presentation | 5/6 - 5/10 (Project M3: 5/6)|

# %% [markdown]
# # 4. Dataset Issues

# %%
# Import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pylab
from sklearn.impute import SimpleImputer
# %matplotlib inline

# %%
kaggle_data = pd.read_csv("../Data/Life_Expectancy_Data.csv")

# %%
kaggle_data.head(6)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
# 5  Afghanistan  2010  Developing              58.8            279.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624         65.0      1154
# 1             64     0.01               73.523582         62.0       492
# 2             66     0.01               73.219243         64.0       430
# 3             69     0.01               78.184215         67.0      2787
# 4             71     0.01                7.097109         68.0      3013
# ...

# %% [markdown]
# We analyzed the dataset collected in step (2) and we found few rows which had incorrect data. Also, after comparing the original data from World Bank (WB) and World Health Organization (WHO) we found out that values were copied incorrectly for few columns.

# %%
# Which year had the highest null values?
start_year = kaggle_data['Year'].unique()[0]
end_year = kaggle_data['Year'].unique()[-1]
for year in range(end_year, start_year+1):
    print("Year:", str(year), str(kaggle_data[kaggle_data['Year'] == year].isnull().sum().sum()))
# Out:
# Year: 2000 204
# Year: 2001 193
# Year: 2002 173
# Year: 2003 154
# Year: 2004 146
# Year: 2005 138
# Year: 2006 131
# Year: 2007 123
# Year: 2008 119
# Year: 2009 116
# Year: 2010 114
# Year: 2011 110
# Year: 2012 112
# Year: 2013 159
# Year: 2014 108
# Year: 2015 463

# %% [markdown]
# In our data manipulation we gathered the initial dataset from Kaggle including our key information in the Dataset as indicated above. Noticeably, the dataset contained missing data for the Year 2015 in particular, although supplementary data was available for Year 2016.

# %%
kaggle_data.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# There are 652 null values for "Population" and most of these null values belong to smaller countries. It was difficult to find data for them on the internet.

# %%
kaggle_data[kaggle_data.isnull().any(axis=1)]['Country'].value_counts().head(10)
# Out:
# Japan                          16
# Antigua and Barbuda            16
# United Republic of Tanzania    16
# Bahrain                        16
# Singapore                      16
# Qatar                          16
# South Sudan                    16
# United Arab Emirates           16
# Kuwait                         16
# Barbados                       16
# Name: Country, dtype: int64

# %% [markdown]
# Smaller countries had missing values for most columns in some cases due to incomplete initial WHO data collection efforts; for these countries we elected to remove the corresponding rows to allow us to proceed with our data analysis since we assume the omission of these countries would have minimal impact on the findings of our overall analysis.
#
# A few columns had incorrect values as in comparision with a corresponding data set gathering from the World Bank; for these columns we chose to remove these columns from our data analysis. We created a new data set using our initial data set for reference using most of the original columns.
#
# For the newer dataset, we decided to confine our analysis for years **2000-2014** to derive consistent incremental analysis for this time period.

# %% [markdown]
# # 5. Dataset Creation and Cleansing

# %%
data = pd.read_pickle("../Data/New/Main_Data/Dataset.pkl")

# %% [markdown]
# We obtained data from World Bank and World Health Organization (WHO) datasets.
# * We used _wbdata_ library to retrieve "Country", "Year", "Population" and "GDP" data.
# * "Status" of each country was retrieved from WorldBank website.
# * **Life_Expectancy**, **Adult_Mortality**, **Infant_Deaths**, **Alcohol**, **Percentage_Expenditure**, **Measles**, **BMI_5-19_years**, **BMI_18+_years**, **Under-Five_Deaths**, **Polio**, **Total_Expenditure**, **Diphtheria**, **Thinness_10-19_years**, **Thinness_5-9_years**, **Income_Composition_Of_Resources**, **Schooling** were retrieved from World Health Organization (WHO) datasets.

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life_Expectancy', 'Adult_Mortality',
#        'Infant_Deaths', 'Alcohol', 'Percentage_Expenditure', 'Measles',
#        'BMI_5-19_years', 'BMI_18+_years', 'Under-Five_Deaths', 'Polio',
#        'Total_Expenditure', 'Diphtheria', 'GDP', 'Population',
#        'Thinness_10-19_years', 'Thinness_5-9_years',
#        'Income_Composition_Of_Resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# Comparing with the kaggle dataset, we removed **HIV/AIDS** and **Hepatitis B** columns because we did not find data for 2000-2014 for all countries in the dataset.
#
# We created two new columns for **BMI**: 'BMI_5-19_years', 'BMI_18+_years' based on the age groups [5-19] years and 18+ years.

# %%
countries_to_be_removed = data[data.isnull().any(axis=1)]['Country'].value_counts()
countries_to_be_removed.head()
# Out:
# Puerto Rico                       15
# Gibraltar                         15
# Virgin Islands (U.S.)             15
# St. Vincent and the Grenadines    15
# Channel Islands                   15
# Name: Country, dtype: int64

# %%
count = 0 # For counting number of countries whose number of maximum null value is 15.
for j in range(0, len(countries_to_be_removed)):
    if countries_to_be_removed[j] == 15:
        count+=1
print(count)
# Out:
# 51

# %% [markdown]
# There are 51 countries in which there are null values in every year (2000 - 2014).
#
# We saved the variable *countries_to_be_removed* into a CSV file. We created another column named _Remove?_ and manually filled "Yes/No" for each country.

# %%
remove_countries = pd.read_csv("../Notes/countries.csv")

# %%
remove_countries.sample(5)
# Out:
#                  Country  Null Values Remove?
# 77            Montenegro            7     Yes
# 0                 Kosovo           15     Yes
# 9    Trinidad and Tobago           15      No
# 102          Afghanistan            2      No
# 128              Hungary            1      No

# %%
len(remove_countries[remove_countries["Remove?"] == "Yes"])
# Out:
# 79

# %% [markdown]
# There are 79 countries where I marked for the countries to be removed from the resulting 131 countries in the list.
# * It was difficult to get data for those countries.
# * Most of the countries have null values for all the years.

# %%
remove_countries_list = remove_countries[remove_countries["Remove?"] == "Yes"]['Country'].tolist()

# %%
for i in range(0, len(remove_countries_list)):
    data.drop(data[data['Country'] == remove_countries_list[i]].index, inplace=True)

# %%
len(data[data.isnull().any(axis=1)])
# Out:
# 125

# %% [markdown]
# Now there are 125 rows which have null values.

# %%
null_columns = data.columns[data.isnull().any()]
null_columns
# Out:
# Index(['Alcohol', 'Percentage_Expenditure', 'Measles', 'Polio',
#        'Total_Expenditure', 'Diphtheria', 'GDP',
#        'Income_Composition_Of_Resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# These are the columns where null values are present.

# %%
for country in data['Country'].unique():
    for column in range(0, len(null_columns)):
        if(data[data['Country'] == country][null_columns[column]].isnull().any()):         
            # DEALING WITH MISSING VALUES
            imp = SimpleImputer(strategy='mean')
            replaced_array = imp.fit_transform(data[data['Country'] == country][[null_columns[column]]])
            # Replacing Values
            count = 0
            start_index = data[data['Country'] == country][null_columns[column]].index[0]
            end_index = data[data['Country'] == country][null_columns[column]].index[-1]
            for row in range(start_index, end_index+1):
                data.at[row, null_columns[column]] = replaced_array[count][0]
                count+=1

# %% [markdown]
# I used **SimpleImputer** from the **sklearn** library to replace NaN values using the "mean" strategy. Each country from 2000 to 2014 with the column where null values are present is given as a parameter to the "fit_transform(...)" function. Mean of each column is calculated and replaced in place of NaN values.

# %%
# Check if data has null values
data.isnull().any()
# Out:
# Country                            False
# Year                               False
# Status                             False
# Life_Expectancy                    False
# Adult_Mortality                    False
# Infant_Deaths                      False
# Alcohol                            False
# Percentage_Expenditure             False
# Measles                            False
# BMI_5-19_years                     False
# BMI_18+_years                      False
# Under-Five_Deaths                  False
# Polio                              False
# Total_Expenditure                  False
# Diphtheria                         False
# GDP                                False
# Population                         False
# Thinness_10-19_years               False
# Thinness_5-9_years                 False
# Income_Composition_Of_Resources    False
# Schooling                          False
# dtype: bool

# %%
# Reset Index
data = data.reset_index(drop=True)

# %% [markdown]
# Finally, we have no null values in the dataset!

# %%
# Changing the data type of each column
data.Life_Expectancy = data.Life_Expectancy.astype(np.float64)
data.Adult_Mortality = data.Adult_Mortality.astype(np.int64)
data.Infant_Deaths = data.Infant_Deaths.astype(np.float64)
data.Alcohol = data.Alcohol.astype(np.float64)
data.Percentage_Expenditure = data.Percentage_Expenditure.astype(np.float64)
data.Measles = data.Measles.astype(np.float64)
data['BMI_5-19_years']  = data['BMI_5-19_years'] .astype(np.float64)
data['BMI_18+_years']  = data['BMI_18+_years'].astype(np.float64)
data.Polio= data.Polio.astype(np.int64)
data['Under-Five_Deaths']= data['Under-Five_Deaths'].astype(np.float64)
data.Total_Expenditure = data.Total_Expenditure .astype(np.float64)
data.Diphtheria = data.Diphtheria .astype(np.int64)
data.GDP = data.GDP.astype(np.float64)
data['Thinness_10-19_years']  = data['Thinness_10-19_years'].astype(np.float64)
data['Thinness_5-9_years']   = data['Thinness_5-9_years'].astype(np.float64)
data.Income_Composition_Of_Resources = data.Income_Composition_Of_Resources.astype(np.float64)
data.Schooling  = data.Schooling.astype(np.float64)

# %% [markdown]
# We changed the data type of each column for further analysis.

# %% [markdown]
# # 6. Data Summarization

# %%
data.head()
# Out:
#        Country  Year      Status  Life_Expectancy  Adult_Mortality  \
# 0  Afghanistan  2014  Low income             63.0              234
# 1  Afghanistan  2013  Low income             62.7              235
# 2  Afghanistan  2012  Low income             62.2              242
# 3  Afghanistan  2011  Low income             61.7              248
# 4  Afghanistan  2010  Low income             61.2              255
#
#    Infant_Deaths  Alcohol  Percentage_Expenditure  Measles  BMI_5-19_years  \
# 0           64.0     0.03                     9.7    492.0            17.2
# 1           66.0     0.03                     8.8    430.0            17.1
# 2           69.0     0.04                     7.9   2787.0            17.0
# 3           71.0     0.04                     8.6   3013.0            16.9
# 4           74.0     0.03                     8.6   1989.0            16.8
#
#      ...      Under-Five_Deaths  Polio  Total_Expenditure  Diphtheria  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2070 entries, 0 to 2069
# Data columns (total 21 columns):
# Country                            2070 non-null object
# Year                               2070 non-null int64
# Status                             2070 non-null object
# Life_Expectancy                    2070 non-null float64
# Adult_Mortality                    2070 non-null int64
# Infant_Deaths                      2070 non-null float64
# Alcohol                            2070 non-null float64
# Percentage_Expenditure             2070 non-null float64
# Measles                            2070 non-null float64
# BMI_5-19_years                     2070 non-null float64
# BMI_18+_years                      2070 non-null float64
# Under-Five_Deaths                  2070 non-null float64
# Polio                              2070 non-null int64
# Total_Expenditure                  2070 non-null float64
# Diphtheria                         2070 non-null int64
# ...

# %% [markdown]
# As per the information from the dataset there are 2070 obseravtions and 21 columns.

# %%
# Unique Countries in the dataset
len(data['Country'].unique())
# Out:
# 138

# %% [markdown]
# There are 138 countries on which we can do analysis on.

# %%
# All years in the dataset for which countries have data to analyse.
data['Year'].unique()
# Out:
# array([2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004,
#        2003, 2002, 2001, 2000])

# %% [markdown]
# We analyse data from **2000 to 2014**.

# %%
data.iloc[[data['Life_Expectancy'].idxmax()]]
# Out:
#      Country  Year       Status  Life_Expectancy  Adult_Mortality  \
# 1020   Japan  2014  High income             83.8               54
#
#       Infant_Deaths  Alcohol  Percentage_Expenditure  Measles  BMI_5-19_years  \
# 1020            2.0     6.71                    10.8    462.0            18.8
#
#         ...      Under-Five_Deaths  Polio  Total_Expenditure  Diphtheria  \
# 1020    ...                    3.0     99              20.28          96
#
#                GDP   Population  Thinness_10-19_years  Thinness_5-9_years  \
# 1020  38109.412113  127276000.0                   2.0                 1.7
#
#       Income_Composition_Of_Resources  Schooling
# 1020                              0.9       12.5
#
# [1 rows x 21 columns]

# %%
data.iloc[[data['Life_Expectancy'].idxmin()]]
# Out:
#     Country  Year      Status  Life_Expectancy  Adult_Mortality  \
# 844   Haiti  2010  Low income             36.2              683
#
#      Infant_Deaths  Alcohol  Percentage_Expenditure  Measles  BMI_5-19_years  \
# 844           23.0     5.77                    10.2      0.0            18.8
#
#        ...      Under-Five_Deaths  Polio  Total_Expenditure  Diphtheria  \
# 844    ...                   58.0     66               5.48          66
#
#             GDP  Population  Thinness_10-19_years  Thinness_5-9_years  \
# 844  662.279518   9999617.0                   4.1                 4.1
#
#      Income_Composition_Of_Resources  Schooling
# 844                             0.41        4.7
#
# [1 rows x 21 columns]

# %% [markdown]
# **Japan** has the highest "Life Expectancy" and **Haiti** has the lowest "Life Expectancy".

# %%
# Show summary statistics
data.describe().transpose()
# Out:
#                                   count          mean           std  \
# Year                             2070.0  2.007000e+03  4.321538e+00
# Life_Expectancy                  2070.0  6.953174e+01  8.973576e+00
# Adult_Mortality                  2070.0  1.875256e+02  1.080044e+02
# Infant_Deaths                    2070.0  3.482012e+01  1.356658e+02
# Alcohol                          2070.0  5.032581e+00  4.085902e+00
# Percentage_Expenditure           2070.0  6.183415e+00  2.490711e+00
# Measles                          2070.0  2.647650e+03  1.173415e+04
# BMI_5-19_years                   2070.0  1.889705e+01  1.325683e+00
# BMI_18+_years                    2070.0  2.496734e+01  2.197830e+00
# Under-Five_Deaths                2070.0  4.800040e+01  1.848080e+02
# Polio                            2070.0  8.660483e+01  1.444649e+01
# Total_Expenditure                2070.0  1.114781e+01  4.367337e+00
# Diphtheria                       2070.0  8.645942e+01  1.515947e+01
# ...

# %% [markdown]
# ### Correlation Analysis

# %%
# Show correlation matrix
data.corr(method='pearson')
# Out:
#                                      Year  Life_Expectancy  Adult_Mortality  \
# Year                             1.000000         0.179612        -0.161746
# Life_Expectancy                  0.179612         1.000000        -0.944142
# Adult_Mortality                 -0.161746        -0.944142         1.000000
# Infant_Deaths                   -0.037770        -0.196137         0.131541
# Alcohol                          0.017794         0.441664        -0.276203
# Percentage_Expenditure           0.106461         0.331709        -0.247908
# Measles                         -0.110982        -0.170774         0.124097
# BMI_5-19_years                   0.128960         0.731774        -0.640838
# BMI_18+_years                    0.157857         0.694729        -0.609968
# Under-Five_Deaths               -0.042970        -0.223588         0.158328
# Polio                            0.151390         0.662965        -0.543994
# ...

# %% [markdown]
# ### How closely is Life Expectancy correlated with other variables?

# %%
data.corr(method='pearson')['Life_Expectancy'].sort_values(ascending=False)
# Out:
# Life_Expectancy                    1.000000
# Income_Composition_Of_Resources    0.840864
# Schooling                          0.765064
# BMI_5-19_years                     0.731774
# BMI_18+_years                      0.694729
# Polio                              0.662965
# Diphtheria                         0.653888
# GDP                                0.616157
# Alcohol                            0.441664
# Total_Expenditure                  0.359315
# Percentage_Expenditure             0.331709
# Year                               0.179612
# Population                         0.018653
# Measles                           -0.170774
# Infant_Deaths                     -0.196137
# Under-Five_Deaths                 -0.223588
# Thinness_5-9_years                -0.596750
# Thinness_10-19_years              -0.605011
# Adult_Mortality                   -0.944142
# Name: Life_Expectancy, dtype: float64

# %% [markdown]
# From the correlation analysis, we find that **Life_Expectancy** is positively associated with **Income_Composition_Of_Resources**, **Schooling**, **BMI_5-19_years**, **BMI_18+_years**, **Polio**, **Diphtheria**, **GDP**, **Alcohol**, **Total_Expenditure**, **Percentage_Expenditure**.

# %% [markdown]
# # 7. Data Visualization

# %%
plt.figure(figsize=(8, 8))

# Create a mask to display only the lower triangle of the matrix
mask = np.zeros_like(data.corr())
mask[np.triu_indices_from(mask)] = True

sns.heatmap(data.corr(), cmap='RdYlGn', vmax=1.0, vmin=-1.0 , mask = mask, linewidths=2)
# cmap is a colormap. For more information, refer to http://matplotlib.org/examples/color/colormaps_reference.html

plt.yticks(rotation=0)
plt.xticks(rotation=90)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5]),
#  <a list of 19 Text xticklabel objects>)

# %% [markdown]
# **Adult mortality, thinness, Measles and infant death** have negative correlation with Life Expectancy.

# %% [markdown]
# ### Exploring variables affecting the life expectancy

# %%
sum_all_by_country = data[['Country','Life_Expectancy','Adult_Mortality','Infant_Deaths','Alcohol','Percentage_Expenditure','Measles','BMI_5-19_years','BMI_18+_years','Under-Five_Deaths','Polio','Total_Expenditure','Diphtheria','GDP',
                          'Population','Thinness_10-19_years','Thinness_5-9_years','Income_Composition_Of_Resources','Schooling']].groupby('Country').sum()
sum_all_by_country.head()
# Out:
#              Life_Expectancy  Adult_Mortality  Infant_Deaths  Alcohol  \
# Country
# Afghanistan            895.6             4048    1186.000000     0.35
# Albania               1113.7             1536      11.735938    76.66
# Algeria               1109.0             1740     304.000000     6.63
# Angola                 822.8             4577    1282.000000    83.93
# Argentina             1129.2             1881     156.000000   119.42
#
#              Percentage_Expenditure       Measles  BMI_5-19_years  \
# Country
# Afghanistan                   141.0  36642.000000           249.8
# Albania                        91.5    985.384615           294.7
# Algeria                        67.0  33256.071429           295.8
# Angola                         53.5  56863.000000           260.0
# Argentina                      91.4     32.000000           303.0
#
#              BMI_18+_years  Under-Five_Deaths  Polio  Total_Expenditure  \
# Country
# ...

# %%
fig = plt.figure(figsize=(35,15))

#categories = np.unique(data['Status'])
#colors = [ lambda x : for i in range(len(categories))]


fig.suptitle("Life Expectancy" , fontsize = 20)

ax1 = fig.add_subplot(331)
ax1.set_title('Adult_Mortality')

ax1.scatter(sum_all_by_country['Life_Expectancy'],
         sum_all_by_country['Adult_Mortality'],
         color='green',
           alpha = 0.5)

ax2 = fig.add_subplot(332)
ax2.set_title('Infant_Deaths')

ax2.scatter(sum_all_by_country['Life_Expectancy'],
            sum_all_by_country['Infant_Deaths'],
            #label= categories,
            color= 'blue',
           alpha = 0.3)
#ax2.legend()

ax3 = fig.add_subplot(333)
ax3.set_title('Alcohol')

ax3.scatter(sum_all_by_country['Life_Expectancy'],
         sum_all_by_country['Alcohol'], 
         color='magenta',
           alpha = 0.6)

ax4 = fig.add_subplot(334)
ax4.set_title('Measles')

ax4.scatter(sum_all_by_country['Life_Expectancy'],
         sum_all_by_country['Measles'], 
         color='orange')

ax5 = fig.add_subplot(335)
ax5.set_title('Polio')

ax5.scatter(sum_all_by_country['Life_Expectancy'],
         sum_all_by_country['Polio'], 
         color='chocolate')

ax6 = fig.add_subplot(336)
ax6.set_title('GDP')

ax6.scatter(sum_all_by_country['Life_Expectancy'],
         sum_all_by_country['Total_Expenditure'], 
         color='teal')

ax7 = fig.add_subplot(337)
ax7.set_title('Percentage_Expenditure')

ax7.scatter(sum_all_by_country['Life_Expectancy'],
         sum_all_by_country['Percentage_Expenditure'], 
         color='green')

ax8 = fig.add_subplot(338)
ax8.set_title('BMI_18+_years')

ax8.scatter(sum_all_by_country['Life_Expectancy'],
         sum_all_by_country['BMI_18+_years'], 
         color='blue')

ax9 = fig.add_subplot(339)
ax9.set_title('Thinness_10-19_years')

ax9.scatter(sum_all_by_country['Life_Expectancy'],
         sum_all_by_country['Thinness_10-19_years'], 
         color='magenta')

plt.show()

# %% [markdown]
# * Adult Mortality, thinness and life expectancy are inversely propotional to each other. So, when Adult mortality and thinness increases life expectancy decreases.
# * Factors like Infant Deaths and Measles do not affect Life Expectancy.
# * Polio (Immunization), percentage of expenditure and life expectancy have a positive correlation.

# %%
sns.countplot(data=data,
                  y = 'Life_Expectancy',
                  hue = 'Status',
                  saturation=1,
                  linewidth=2)
plt.legend(loc = 'upper right',frameon = False)
plt.figsize = (25,100)

# %% [markdown]
# The plot shows that "High income countries" have highest life expectancy, where as "Low income countries" have lower life expectancy.

# %% [markdown]
# ### Impact of Healthcare Expenditure on Life expectancy

# %%
g= sns.FacetGrid(data,col="Status")
g.map(plt.bar,"Life_Expectancy","Total_Expenditure")

# %% [markdown]
# Life Expectancy positively correlates with Total Expenditure. So, when Total Expenditure increases Life Expectancy increases irrespective of "Status of the country".

# %%
sum_life_by_status = data[['Status','Life_Expectancy']].groupby('Status').sum()
sum_life_by_status
# Out:
#                      Life_Expectancy
# Status
# High income                  52613.9
# Low income                   20832.9
# Lower middle income          29912.3
# Upper middle income          40571.6

# %%
sum_life_by_status.plot(kind = 'bar',legend = False)

# %% [markdown]
# "High income Countries" have the highest life expectancy and "Low income countries" have the lowest life expectancy.

# %% [markdown]
# ### Adult mortality rates with respect to Status of the Country

# %%
# Generate grouped data first
grouped = data.groupby('Status')

# Then draw the plot by group
fig, ax = plt.subplots()
for name, group in grouped:
    ax.plot(group.Life_Expectancy, group.Adult_Mortality, marker='o', linestyle='', ms=5, label=name)
ax.legend(['High income','Low income','Lower middleincome','Upper middle income'])
plt.xlabel('Life expectancy')
plt.ylabel('Adult mortality')
plt.show()

# %% [markdown]
# High income Countries have higher Life Expectancy and lower Adult mortality rates, where as low income countries have lowest Life Expectancy.

# %%
scatterplot = pd.plotting.scatter_matrix(sum_all_by_country,
                            alpha=0.3,
                            figsize=(50, 50),
                            diagonal='kde',
                            marker='o',
                            grid=True)

# %% [markdown]
# The plot shows the relationship between the variables in the dataset.

# %% [markdown]
# ## Impact of Income Resource and Schooling on Life Expectency

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
axes[0].plot(data['Life_Expectancy'], data['Income_Composition_Of_Resources'], 'go', label='Income_Composition_Of_Resources',alpha=0.5)
axes[0].set_title("Income Composition Vs Life Expectency")
axes[1].plot(data['Life_Expectancy'], data['Schooling'], 'b*', label='Schooling',alpha = 0.5)
axes[1].set_title("Schooling Vs Life Expectency")
# Out:
# Text(0.5, 1.0, 'Schooling Vs Life Expectency')

# %% [markdown]
# * With an increase in income composition, there is also an increase in life expectancy.
# * There is an increase in life expectancy when number of years of schooling is higher in countries.
